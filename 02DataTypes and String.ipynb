# %% [markdown]
# # Data Types
# ### -Numeric --> int, float, complex ---> Whole numbers, decimals, and imaginary numbers. ----> 42, 3.14, 2+3j
# ### -Text --> str(string) ---> Character sequences (strings) enclosed in quotes. ----> "Hello, Python!"
# ### -Sequence --> list, tuple, range ---> Ordered collections of items. ----> [1, 2, 3], (4, 5), range(5)
# ### -Mapping --> dict ---> Unordered key-value pairs. ----> {"name": "Alice", "age": 25}
# ### -Set --> set, frozenset ---> Unordered collections of unique elements. ----> {1, 2, 3}
# ### -Boolean --> bool ---> Logical states representing truth values. ----> True, False
# ### -None --> NoneType ---> Represents the absence of a value. ----> None

# %% [markdown]
# ## 1. Numeric Types

# %% [markdown]
# #### int:

# %% [markdown]
# #### Positive or negative whole numbers with unlimited precision

# %%
# example
i=20
type(1)
# Out:
# int

# %% [markdown]
# ## float :
# ### Real numbers containing a decimal point.

# %%
# example for float(contains decimal value) data type
f = 54.23
type(f)
# Out:
# float

# %%
f1=20.90
type(f1)
# Out:
# float

# %% [markdown]
# ## complex :
# #### Complex numbers written with a j or J for the imaginary part.
# ### example :

# %%
c = 4 + 3j # in complex data type we can use only j/J not any other alphabet
type(c)
# Out:
# complex

# %%
c1=5+6J
type(c1)
# Out:
# complex

# %%
c2 = 8 + 2k    # it will be gives error
type(c2)
# Out:
#   Cell In[28], line 1
#     c2 = 8 + 2k    # it will be gives error
#              ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ## c.real
#
# ### c.real is used to get the real part of a complex number in Python.

# %%
#    4 + 3j
#    ↑   ↑
#  Real  Imaginary

c.real # c.real means real value first value
# Out:
# 4.0

# %%
#    4 + 3j
#    ↑   ↑
#  Real  Imaginary

c.imag #  c.imag means imaginary value j joining value
# Out:
# 3.0

# %%
type (c)
# Out:
# complex

# %% [markdown]
# # 2. Text Type :
# ### Used to manage textual data.
# ### str :
# #### Strings are immutable sequences of Unicode characters wrapped in single, double, or triple quotes.
# ### Example :

# %% [markdown]
# ### !This is single quote string also use for single line string

# %%
str1 = 'Wellcome' # this is single quote string also use for single line string
print(str1)
type(str1)
# Out:
# Wellcome
# str

# %% [markdown]
# ### " This is doublequotes string " uesed for single line string

# %%
s2 = " This is doublequotes string "    # uesed for single line string
print(s2)
type(s2)
# Out:
#  This is doublequotes string
# str

# %% [markdown]
#  ### ''' This also a string this is used for write multiline string '''

# %%
s3 = ''' This also a string
this is used for write multiline string ''' 
type(s3)
print(s3)
type(s3)
# Out:
#  This also a string
# this is used for write multiline string
# str

# %% [markdown]
# # 3. Sequence Types :
# ### Used to store multiple data items in an ordered arrangement.
# ## Example :
# #### list :
# ##### Mutable (changeable) sequences that can store mixed data types.
# ## Example :

# %%
l =  [1, "apple", True]
print(type(l))
print(l)
# Out:
# <class 'list'>
# [1, 'apple', True]

# %%
l1 =  (3, "Mango", False)   # we can not use round brackets in list, when we use round brackets type is changed list to tuple
print(l1)
print(type(l1))
# Out:
# (3, 'Mango', False)
# <class 'tuple'>

# %%
l2 =  {1, "apple", True} # also we can not  use curly brackets in list, when we use curly brackets type is changed list to set
type(l2)
# Out:
# set

# %%
l3 =  <1, "apple", True>  # also we can not use angle brackets
type(l2)
# Out:
#   Cell In[43], line 1
#     l3 =  <1, "apple", True>  # also we can not use angle brackets
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## tuple :
# ### Immutable (unchangeable) sequences primarily used to protect data from accidental alterations.
# ### Example :

# %%
t  = (10.5, 20.3)
print(t)
type(t)
# Out:
# (10.5, 20.3)
# tuple

# %% [markdown]
# ## same rules here like list rules
# ### range :
# #### Represents an immutable sequence of numbers, commonly utilized for looping specific frequencies.
# ### Example :

# %%
r = range(1, 10)
print(r)
print(type(r))
# Out:
# range(1, 10)
# <class 'range'>

# %% [markdown]
# ## 4. Mapping Type :
# #### Used to store data sets that have relationships.
# ### dict :
# #### Dictionaries map unique keys to specific values. They are highly efficient for looking up data.
# ### Example :

# %%
d = {"id": 101, "role": "admin"}
type(d)
# Out:
# dict

# %% [markdown]
# ## 5. Set Types
# #### Used for membership testing and deduplication.
# ### set :
# #### An unordered collection containing unique items.
# ### Example :

# %%
s = {101, 102, 103}
print(s)
print(type(s))
# Out:
# {101, 102, 103}
# <class 'set'>

# %% [markdown]
# ### frozenset:
# #### An immutable variation of a standard set.
# ## Example :

# %%
fr = frozenset([1, 2, 3]) #You cannot add or remove values.
print(fr)
print(type(fr))
# Out:
# frozenset({1, 2, 3})
# <class 'frozenset'>

# %% [markdown]
# # 6. Boolean and None Types :
# #### Used for controlling program flow and logic.
# ## bool :
# #### Evaluates exclusively to True or False.
# ## Example :

# %%
b = True
print(b)
print(type(b))
# Out:
# True
# <class 'bool'>

# %%
b1 = False
print(type(b1))
print(b1)
id(b1)
# Out:
# <class 'bool'>
# False
# 140716498074112

# %%
print(b)
# Out:
# True

# %%
b1
# Out:
# False

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True+False
# Out:
# 1

# %%
False+True
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
False * True
# Out:
# 0

# %%
False / True
# Out:
# 0.0

# %%
False // True
# Out:
# 0

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
True // False
