# %%
## type casting is the one data type to another date the is called type casting

# %%
thiru="10"
varshini=int(thiru)
print(varshini)
print(type(varshini))
# Out:
# 10
# <class 'int'>

# %%
thiru=10
varshini="20"
love=thiru+varshini
print(love)
