# %%
## type casting is the one data type to another date the is called type casting

# %%
thiru="10"
varshini=int(thiru)
print(varshini)
print(type(varshini))
# Out:
# 10
# <class 'int'>

# %%
thiru=10
varshini="20"
love=thiru+varshini
print(love)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 thiru=10
#       2 varshini="20"
# ----> 3 love=thiru+varshini
#       4 print(love)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
##changing the type
thiru=10
varshini=int("20")
love=thiru+varshini
print(love)
# Out:
# 30
