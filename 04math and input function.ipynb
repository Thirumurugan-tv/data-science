# %% [markdown]
# #  Math Module

# %%
sqrt(25)  #got an error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sqrt(25)  #got an error
#
# NameError: name 'sqrt' is not defined

# %%
import math
math. sqrt(25)
# Out:
# 5.0

# %% [markdown]
# #### floor and Ceil Function

# %%
#floor means lower whole number
math.floor(3.5)
# Out:
# 3

# %%
math.floor(5.9)
# Out:
# 5

# %%
math.floor(4.9)
# Out:
# 4

# %%
#ceil means uper whole number

math.ceil(3.5)
# Out:
# 4

# %%
math.ceil(7.9)
# Out:
# 8

# %%
# math pow
math.pow(2,3)
# Out:
# 8.0

# %%
math.pow(4,6)
# Out:
# 4096.0

# %%
import math as a
print(a.pow(2,3))
print(a.floor(4.3))
print(a.ceil(2.3))
print(a.sqrt(25))
print(a.pow(4,2))
# Out:
# 8.0
# 4
# 3
# 5.0
# 16.0

# %%
# using specipic math fucntion

from math import pow, floor, ceil, sqrt
print(pow(5,3))
print(sqrt(49))
print(floor(4.9))
print(ceil(4.9))
print(sqrt(36))
print(pow(5,2))
# Out:
# 125.0
# 7.0
# 4
# 5
# 6.0
# 25.0

# %% [markdown]
# # Help
#
# #help(math)

# %%
help(math) # here i give math so this gives information about math anything you give in python it will give

# %%
# importing all function

from math import *   # (* - select all inbuild functiom)
print(pow(5,3))
print(sqrt(49))
print(floor(4.9))
print(ceil(4.9))
print(sqrt(36))
print(pow(5,2))
# Out:
# 125.0
# 7.0
# 4
# 5
# 6.0
# 25.0

# %% [markdown]
# # Input Function

# %%
x=input()
x
# Out:
#  thiru
# 'thiru'

# %%
x=input()
y=input()
z=x+y
print(z)
# Out:
#  78
#  32
# 7832

# %%
x = int(input('Enter the first number'))   # Converting a string to integer (number) using int keywoerd
y = int(input('Enter the second number'))
z = x+y
print(z)
# Out:
# Enter the first number 23
# Enter the second number 23
# 46

# %%
st = input('enter a string')
print(st)
# Out:
# enter a string thiru
# thiru

# %%
thiru=eval(input("Enter the Expression")) # Eval Keyword is used for an expression
print(thiru)
# Out:
# Enter the Expression 2+5
# 7

# %% [markdown]
# #
